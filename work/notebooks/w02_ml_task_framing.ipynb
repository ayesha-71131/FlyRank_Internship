# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha-71131/FlyRank_Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ayesha-71131/FlyRank_Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# Lane 2 is a ranking/scoring task. I need to produce a priority score for each page so a strategist can review the highest-scoring ones first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Import libraries
import pandas as pd
import numpy as np

# Load the dataset from where you uploaded it
df = pd.read_csv('/content/sample_data/content_refresh_anonymized.csv')

# Verify it loaded correctly
print("✅ Data loaded successfully!")

# Show ranking concept
print("Ranking task: ordering pages by priority")
print(f"Total pages to rank: {len(df)}")
# Out:
# ✅ Data loaded successfully!
# Ranking task: ordering pages by priority
# Total pages to rank: 30000

# %% [markdown]
# ## 2. Target or proxy
#
# My target is declined_next_30d — whether impressions dropped >20% in the next 30 days. This is an observed outcome, not a rule.

# %%
# Show current trend_direction (what NOT to use)
print("Current trend_direction (rule-based, NOT my target):")
print(df['trend_direction'].value_counts())
# Out:
# Current trend_direction (rule-based, NOT my target):
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# My metric is Precision@20 — of top 20 recommendations, how many actually declined?

# %%
# Show capacity constraint
print(f"If strategist reviews 20 pages/week:")
print(f"Precision@20 = (correct in top 20) / 20")
# Out:
# If strategist reviews 20 pages/week:
# Precision@20 = (correct in top 20) / 20

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row = one page, identified by unique content_id.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Prove one row = one page
print(f"Total rows: {len(df)}")
print(f"Unique content_ids: {df['content_id'].nunique()}")
print(df[['content_id', 'impressions_90d', 'trend_direction']].head())
# Out:
# Total rows: 30000
# Unique content_ids: 30000
#              content_id  impressions_90d trend_direction
# 0  content_304f48230142             3803            down
# 1  content_a1fb4e703a9e            15320            down
# 2  content_9aa793d4d895            12581            down
# 3  content_331d6c4de07b            11751          stable
# 4  content_d99b7a2d90ca            19140            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# ML beats rules because signals interact in complex ways, and simple rules like search_volume fail (correlation = 0.001).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Show why rules fail
corr = df['search_volume'].corr(df['impressions_90d'])
print(f"Search volume vs impressions: {corr:.3f}")
# Out:
# Search volume vs impressions: 0.001

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
